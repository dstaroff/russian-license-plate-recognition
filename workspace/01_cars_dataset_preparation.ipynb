# %% [markdown]
# # Step 1: Cars dataset preparation

# %% [markdown]
# ## Imports

# %%
from src.local_utils.constants import (
    RU_CARS_IMAGES_PATH,
    RU_CARS_ANNOTATIONS_PATH,
    CARS_TRAINING_SET_FILE,
    CARS_VALIDATION_SET_FILE,
    CARS_LABELS_FILE,
)
from src.local_utils.dataset import (
    clean_dataset,
    split_dataset,
    get_labels,
)

# %% [markdown]
# ## Clean dataset

# %%
clean_dataset(RU_CARS_IMAGES_PATH, RU_CARS_ANNOTATIONS_PATH)
# Out:
# Cleaning dataset
# 	Verifying annotations
# 		Annotation "000.xml" for "000.jpg" verified
# 		Annotation "001.xml" for "001.jpg" verified
# 		Annotation "002.xml" for "002.jpg" verified
# 		Annotation "003.xml" for "003.jpg" verified
# 		Annotation "004.xml" for "004.jpg" verified
# 		Annotation "005.xml" for "005.jpg" verified
# 		Annotation "006.xml" for "006.jpg" verified
# 		Annotation "007.xml" for "007.jpg" verified
# 		Annotation "008.xml" for "008.jpg" verified
# 		Annotation "009.xml" for "009.jpg" verified
# 		Annotation "010.xml" for "010.jpg" verified
# 		Annotation "011.xml" for "011.jpg" verified
# 		Annotation "012.xml" for "012.jpg" verified
# 		Annotation "013.xml" for "013.jpg" verified
# 		Annotation "014.xml" for "014.jpg" verified
# 		Annotation "015.xml" for "015.jpg" verified
# 		Annotation "016.xml" for "016.jpg" verified
# 		Annotation "017.xml" for "017.jpg" verified
# 		Annotation "018.xml" for "018.jpg" verified
# ...

# %% [markdown]
# ## Split dataset

# %%
split_dataset(RU_CARS_IMAGES_PATH, RU_CARS_ANNOTATIONS_PATH, CARS_TRAINING_SET_FILE, CARS_VALIDATION_SET_FILE)
# Out:
# Splitting dataset to training & validation sets
# 	Dataset size: 220
# 	Using validation split = 20.0%
# 		Training set size: 176
# 		Validation set size: 44
# 	Training set:
# 		000.jpg 000.xml
# 		001.jpg 001.xml
# 		004.jpg 004.xml
# 		005.jpg 005.xml
# 		006.jpg 006.xml
# 		007.jpg 007.xml
# 		009.jpg 009.xml
# 		010.jpg 010.xml
# 		011.jpg 011.xml
# 		012.jpg 012.xml
# 		015.jpg 015.xml
# 		016.jpg 016.xml
# 		017.jpg 017.xml
# 		020.jpg 020.xml
# 		022.jpg 022.xml
# 		023.jpg 023.xml
# 		024.jpg 024.xml
# 		025.jpg 025.xml
# 		026.jpg 026.xml
# 		027.jpg 027.xml
# 		028.jpg 028.xml
# 		029.jpg 029.xml
# 		030.jpg 030.xml
# 		031.jpg 031.xml
# 		032.jpg 032.xml
# 		033.jpg 033.xml
# 		034.jpg 034.xml
# 		035.jpg 035.xml
# 		036.jpg 036.xml
# 		037.jpg 037.xml
# 		038.jpg 038.xml
# 		040.jpg 040.xml
# 		041.jpg 041.xml
# 		042.jpg 042.xml
# 		044.jpg 044.xml
# 		048.jpg 048.xml
# 		049.jpg 049.xml
# 		050.jpg 050.xml
# 		051.jpg 051.xml
# 		052.jpg 052.xml
# 		053.jpg 053.xml
# ...

# %% [markdown]
# ## Get labels

# %%
get_labels(RU_CARS_ANNOTATIONS_PATH, CARS_LABELS_FILE)
# Out:
# Labels:
# 	PLATE
# 	CAR
#
# 	Done
