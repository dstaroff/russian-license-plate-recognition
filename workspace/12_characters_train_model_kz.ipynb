# %% [markdown]
# # Step 12: Training characters classifier (KZ)

# %% [markdown]
# ## Imports

# %%
import os

import cv2
import matplotlib.pyplot as plt
import numpy as np
from tensorflow import keras
from tensorflow.keras.callbacks import ModelCheckpoint

from src.local_utils.constants import (
    KZ_CHARACTERS_IMAGES_PATH,
    KZ_CHARACTERS_BEST_MODEL_FILE,
    KZ_CHARACTERS_HISTORY_FILE,
    VALIDATION_SPLIT
)
from src.local_utils.history import history2csv, csv2history
from src.networks.character_classifier import CharacterClassifier

# %% [markdown]
# ## Preparing the data

# %%
X = []
Y = []

classnames = os.listdir(KZ_CHARACTERS_IMAGES_PATH)
classname_paths = list(map(lambda clsname: os.path.join(KZ_CHARACTERS_IMAGES_PATH, clsname), classnames))
for classname_index, classname_path in enumerate(classname_paths):
    image_pathes = list(map(lambda filename: os.path.join(classname_path, filename), os.listdir(classname_path)))
    for image_path in image_pathes:
        image = cv2.imread(image_path)
        X.append(image.astype('float32') / 255)
        Y.append(classname_index)

X = np.array(X)
Y = keras.utils.to_categorical(np.array(Y))

indexes = None
for _ in range(5):
    indexes = np.random.permutation(len(X))

train_data = X[indexes]
train_labels_cat = Y[indexes]

# now set-aside 10% of the train_data/labels as the
# cross-validation sets
val_count = int(VALIDATION_SPLIT * len(train_data))

# first pick validation set from train_data/labels
val_data = train_data[:val_count,:]
val_labels_cat = train_labels_cat[:val_count,:]

# leave rest in training set
train_data2 = train_data[val_count:,:]
train_labels_cat2 = train_labels_cat[val_count:,:]

# %% [markdown]
# ## Loading model

# %%
model = CharacterClassifier(len(classnames))

# %%
if os.path.exists(KZ_CHARACTERS_BEST_MODEL_FILE):
    model.load_weights(KZ_CHARACTERS_BEST_MODEL_FILE)

# %% [markdown]
# ## Training model

# %%
history = model.fit(
    train_data2,
    train_labels_cat2,
    epochs=100,
    batch_size=64,
    validation_data=(val_data, val_labels_cat),
    verbose=2,
    callbacks=[
        ModelCheckpoint(
            filepath=KZ_CHARACTERS_BEST_MODEL_FILE,
            save_weights_only=True,
            monitor='val_accuracy',
            mode='max',
            save_best_only=True,
        )
    ]
)
# Out:
# Epoch 1/100
# 23/23 - 0s - loss: 2.5297 - accuracy: 0.3992 - val_loss: 1.1838 - val_accuracy: 0.7311
# Epoch 2/100
# 23/23 - 0s - loss: 0.6219 - accuracy: 0.8852 - val_loss: 0.2877 - val_accuracy: 0.9440
# Epoch 3/100
# 23/23 - 0s - loss: 0.2614 - accuracy: 0.9440 - val_loss: 0.1564 - val_accuracy: 0.9664
# Epoch 4/100
# 23/23 - 0s - loss: 0.1189 - accuracy: 0.9692 - val_loss: 0.1195 - val_accuracy: 0.9636
# Epoch 5/100
# 23/23 - 0s - loss: 0.0750 - accuracy: 0.9783 - val_loss: 0.0649 - val_accuracy: 0.9860
# Epoch 6/100
# 23/23 - 0s - loss: 0.0555 - accuracy: 0.9867 - val_loss: 0.0562 - val_accuracy: 0.9804
# Epoch 7/100
# 23/23 - 0s - loss: 0.0450 - accuracy: 0.9874 - val_loss: 0.0707 - val_accuracy: 0.9720
# Epoch 8/100
# 23/23 - 0s - loss: 0.0364 - accuracy: 0.9902 - val_loss: 0.0516 - val_accuracy: 0.9860
# Epoch 9/100
# 23/23 - 0s - loss: 0.0411 - accuracy: 0.9909 - val_loss: 0.0493 - val_accuracy: 0.9832
# Epoch 10/100
# 23/23 - 0s - loss: 0.0273 - accuracy: 0.9923 - val_loss: 0.0772 - val_accuracy: 0.9832
# Epoch 11/100
# 23/23 - 0s - loss: 0.0297 - accuracy: 0.9916 - val_loss: 0.0517 - val_accuracy: 0.9776
# Epoch 12/100
# 23/23 - 0s - loss: 0.0238 - accuracy: 0.9930 - val_loss: 0.0385 - val_accuracy: 0.9860
# Epoch 13/100
# 23/23 - 0s - loss: 0.0179 - accuracy: 0.9951 - val_loss: 0.0573 - val_accuracy: 0.9832
# Epoch 14/100
# 23/23 - 0s - loss: 0.0200 - accuracy: 0.9944 - val_loss: 0.0321 - val_accuracy: 0.9888
# Epoch 15/100
# 23/23 - 0s - loss: 0.0127 - accuracy: 0.9951 - val_loss: 0.0533 - val_accuracy: 0.9860
# Epoch 16/100
# 23/23 - 0s - loss: 0.0379 - accuracy: 0.9874 - val_loss: 0.0865 - val_accuracy: 0.9832
# Epoch 17/100
# 23/23 - 0s - loss: 0.0371 - accuracy: 0.9909 - val_loss: 0.0862 - val_accuracy: 0.9776
# Epoch 18/100
# 23/23 - 0s - loss: 0.0401 - accuracy: 0.9888 - val_loss: 0.2239 - val_accuracy: 0.9300
# Epoch 19/100
# 23/23 - 0s - loss: 0.0404 - accuracy: 0.9881 - val_loss: 0.0767 - val_accuracy: 0.9860
# Epoch 20/100
# 23/23 - 0s - loss: 0.0257 - accuracy: 0.9909 - val_loss: 0.0614 - val_accuracy: 0.9888
# Epoch 21/100
# 23/23 - 0s - loss: 0.0193 - accuracy: 0.9965 - val_loss: 0.0365 - val_accuracy: 0.9860
# Epoch 22/100
# 23/23 - 0s - loss: 0.0091 - accuracy: 0.9979 - val_loss: 0.0401 - val_accuracy: 0.9860
# Epoch 23/100
# 23/23 - 0s - loss: 0.0076 - accuracy: 0.9979 - val_loss: 0.0690 - val_accuracy: 0.9832
# Epoch 24/100
# 23/23 - 0s - loss: 0.0200 - accuracy: 0.9930 - val_loss: 0.0636 - val_accuracy: 0.9832
# Epoch 25/100
# 23/23 - 0s - loss: 0.0128 - accuracy: 0.9958 - val_loss: 0.0675 - val_accuracy: 0.9832
# Epoch 26/100
# 23/23 - 0s - loss: 0.0046 - accuracy: 0.9993 - val_loss: 0.0238 - val_accuracy: 0.9888
# Epoch 27/100
# 23/23 - 0s - loss: 0.0041 - accuracy: 0.9993 - val_loss: 0.0469 - val_accuracy: 0.9832
# Epoch 28/100
# 23/23 - 0s - loss: 0.0071 - accuracy: 0.9965 - val_loss: 0.0242 - val_accuracy: 0.9888
# Epoch 29/100
# 23/23 - 0s - loss: 0.0103 - accuracy: 0.9979 - val_loss: 0.0295 - val_accuracy: 0.9860
# Epoch 30/100
# 23/23 - 0s - loss: 0.0021 - accuracy: 0.9993 - val_loss: 0.0385 - val_accuracy: 0.9860
# Epoch 31/100
# 23/23 - 0s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0349 - val_accuracy: 0.9832
# Epoch 32/100
# 23/23 - 0s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0350 - val_accuracy: 0.9888
# Epoch 33/100
# 23/23 - 0s - loss: 0.0018 - accuracy: 0.9993 - val_loss: 0.0457 - val_accuracy: 0.9860
# Epoch 34/100
# 23/23 - 0s - loss: 0.0015 - accuracy: 0.9993 - val_loss: 0.0392 - val_accuracy: 0.9860
# Epoch 35/100
# 23/23 - 0s - loss: 4.2078e-04 - accuracy: 1.0000 - val_loss: 0.0253 - val_accuracy: 0.9860
# Epoch 36/100
# 23/23 - 0s - loss: 3.2505e-04 - accuracy: 1.0000 - val_loss: 0.0302 - val_accuracy: 0.9860
# Epoch 37/100
# 23/23 - 0s - loss: 3.1914e-04 - accuracy: 1.0000 - val_loss: 0.0310 - val_accuracy: 0.9860
# Epoch 38/100
# 23/23 - 0s - loss: 2.5949e-04 - accuracy: 1.0000 - val_loss: 0.0256 - val_accuracy: 0.9860
# Epoch 39/100
# 23/23 - 0s - loss: 2.5333e-04 - accuracy: 1.0000 - val_loss: 0.0314 - val_accuracy: 0.9860
# Epoch 40/100
# 23/23 - 0s - loss: 2.3597e-04 - accuracy: 1.0000 - val_loss: 0.0281 - val_accuracy: 0.9888
# Epoch 41/100
# 23/23 - 0s - loss: 1.8431e-04 - accuracy: 1.0000 - val_loss: 0.0258 - val_accuracy: 0.9860
# Epoch 42/100
# 23/23 - 0s - loss: 1.8250e-04 - accuracy: 1.0000 - val_loss: 0.0272 - val_accuracy: 0.9860
# Epoch 43/100
# 23/23 - 0s - loss: 1.5859e-04 - accuracy: 1.0000 - val_loss: 0.0247 - val_accuracy: 0.9888
# Epoch 44/100
# 23/23 - 0s - loss: 1.4482e-04 - accuracy: 1.0000 - val_loss: 0.0286 - val_accuracy: 0.9888
# Epoch 45/100
# 23/23 - 0s - loss: 1.4495e-04 - accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9888
# Epoch 46/100
# 23/23 - 0s - loss: 1.3570e-04 - accuracy: 1.0000 - val_loss: 0.0268 - val_accuracy: 0.9888
# Epoch 47/100
# 23/23 - 0s - loss: 1.2892e-04 - accuracy: 1.0000 - val_loss: 0.0257 - val_accuracy: 0.9888
# Epoch 48/100
# 23/23 - 0s - loss: 1.5234e-04 - accuracy: 1.0000 - val_loss: 0.0272 - val_accuracy: 0.9860
# Epoch 49/100
# 23/23 - 0s - loss: 1.4857e-04 - accuracy: 1.0000 - val_loss: 0.0225 - val_accuracy: 0.9916
# Epoch 50/100
# 23/23 - 0s - loss: 1.3911e-04 - accuracy: 1.0000 - val_loss: 0.0275 - val_accuracy: 0.9860
# Epoch 51/100
# 23/23 - 0s - loss: 1.0646e-04 - accuracy: 1.0000 - val_loss: 0.0246 - val_accuracy: 0.9888
# Epoch 52/100
# 23/23 - 0s - loss: 1.0005e-04 - accuracy: 1.0000 - val_loss: 0.0257 - val_accuracy: 0.9860
# Epoch 53/100
# 23/23 - 0s - loss: 9.5055e-05 - accuracy: 1.0000 - val_loss: 0.0253 - val_accuracy: 0.9888
# Epoch 54/100
# 23/23 - 0s - loss: 9.0417e-05 - accuracy: 1.0000 - val_loss: 0.0256 - val_accuracy: 0.9860
# Epoch 55/100
# 23/23 - 0s - loss: 8.8503e-05 - accuracy: 1.0000 - val_loss: 0.0259 - val_accuracy: 0.9860
# Epoch 56/100
# 23/23 - 0s - loss: 8.5178e-05 - accuracy: 1.0000 - val_loss: 0.0270 - val_accuracy: 0.9860
# Epoch 57/100
# 23/23 - 0s - loss: 8.6123e-05 - accuracy: 1.0000 - val_loss: 0.0238 - val_accuracy: 0.9888
# Epoch 58/100
# 23/23 - 0s - loss: 9.2696e-05 - accuracy: 1.0000 - val_loss: 0.0275 - val_accuracy: 0.9860
# Epoch 59/100
# 23/23 - 0s - loss: 8.2070e-05 - accuracy: 1.0000 - val_loss: 0.0256 - val_accuracy: 0.9860
# Epoch 60/100
# 23/23 - 0s - loss: 7.6850e-05 - accuracy: 1.0000 - val_loss: 0.0236 - val_accuracy: 0.9860
# Epoch 61/100
# 23/23 - 0s - loss: 7.1081e-05 - accuracy: 1.0000 - val_loss: 0.0261 - val_accuracy: 0.9860
# Epoch 62/100
# 23/23 - 0s - loss: 6.9578e-05 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 0.9860
# Epoch 63/100
# 23/23 - 0s - loss: 6.5391e-05 - accuracy: 1.0000 - val_loss: 0.0250 - val_accuracy: 0.9860
# Epoch 64/100
# 23/23 - 0s - loss: 7.1038e-05 - accuracy: 1.0000 - val_loss: 0.0222 - val_accuracy: 0.9888
# Epoch 65/100
# 23/23 - 0s - loss: 6.6933e-05 - accuracy: 1.0000 - val_loss: 0.0268 - val_accuracy: 0.9860
# Epoch 66/100
# 23/23 - 0s - loss: 6.1382e-05 - accuracy: 1.0000 - val_loss: 0.0240 - val_accuracy: 0.9860
# Epoch 67/100
# 23/23 - 0s - loss: 5.9535e-05 - accuracy: 1.0000 - val_loss: 0.0254 - val_accuracy: 0.9888
# Epoch 68/100
# 23/23 - 0s - loss: 5.6139e-05 - accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9860
# Epoch 69/100
# 23/23 - 0s - loss: 5.8497e-05 - accuracy: 1.0000 - val_loss: 0.0255 - val_accuracy: 0.9860
# Epoch 70/100
# 23/23 - 0s - loss: 6.0910e-05 - accuracy: 1.0000 - val_loss: 0.0254 - val_accuracy: 0.9860
# Epoch 71/100
# 23/23 - 0s - loss: 5.3751e-05 - accuracy: 1.0000 - val_loss: 0.0257 - val_accuracy: 0.9860
# Epoch 72/100
# 23/23 - 0s - loss: 5.2176e-05 - accuracy: 1.0000 - val_loss: 0.0239 - val_accuracy: 0.9888
# Epoch 73/100
# 23/23 - 0s - loss: 4.8964e-05 - accuracy: 1.0000 - val_loss: 0.0249 - val_accuracy: 0.9860
# Epoch 74/100
# 23/23 - 0s - loss: 4.8491e-05 - accuracy: 1.0000 - val_loss: 0.0244 - val_accuracy: 0.9860
# Epoch 75/100
# 23/23 - 0s - loss: 4.9346e-05 - accuracy: 1.0000 - val_loss: 0.0240 - val_accuracy: 0.9888
# Epoch 76/100
# 23/23 - 0s - loss: 4.9653e-05 - accuracy: 1.0000 - val_loss: 0.0258 - val_accuracy: 0.9860
# Epoch 77/100
# 23/23 - 0s - loss: 4.4438e-05 - accuracy: 1.0000 - val_loss: 0.0240 - val_accuracy: 0.9860
# Epoch 78/100
# 23/23 - 0s - loss: 4.1487e-05 - accuracy: 1.0000 - val_loss: 0.0257 - val_accuracy: 0.9860
# Epoch 79/100
# 23/23 - 0s - loss: 4.1771e-05 - accuracy: 1.0000 - val_loss: 0.0249 - val_accuracy: 0.9860
# Epoch 80/100
# 23/23 - 0s - loss: 3.9502e-05 - accuracy: 1.0000 - val_loss: 0.0252 - val_accuracy: 0.9860
# Epoch 81/100
# 23/23 - 0s - loss: 3.8514e-05 - accuracy: 1.0000 - val_loss: 0.0251 - val_accuracy: 0.9860
# Epoch 82/100
# 23/23 - 0s - loss: 3.7398e-05 - accuracy: 1.0000 - val_loss: 0.0252 - val_accuracy: 0.9860
# Epoch 83/100
# 23/23 - 0s - loss: 3.6858e-05 - accuracy: 1.0000 - val_loss: 0.0256 - val_accuracy: 0.9860
# Epoch 84/100
# 23/23 - 0s - loss: 3.7189e-05 - accuracy: 1.0000 - val_loss: 0.0258 - val_accuracy: 0.9860
# Epoch 85/100
# 23/23 - 0s - loss: 3.4377e-05 - accuracy: 1.0000 - val_loss: 0.0249 - val_accuracy: 0.9860
# Epoch 86/100
# 23/23 - 0s - loss: 3.5671e-05 - accuracy: 1.0000 - val_loss: 0.0240 - val_accuracy: 0.9860
# Epoch 87/100
# 23/23 - 0s - loss: 3.3325e-05 - accuracy: 1.0000 - val_loss: 0.0252 - val_accuracy: 0.9860
# Epoch 88/100
# 23/23 - 0s - loss: 3.2002e-05 - accuracy: 1.0000 - val_loss: 0.0255 - val_accuracy: 0.9860
# Epoch 89/100
# 23/23 - 0s - loss: 3.2602e-05 - accuracy: 1.0000 - val_loss: 0.0251 - val_accuracy: 0.9860
# Epoch 90/100
# 23/23 - 0s - loss: 3.4488e-05 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9832
# Epoch 91/100
# 23/23 - 0s - loss: 3.1407e-05 - accuracy: 1.0000 - val_loss: 0.0269 - val_accuracy: 0.9860
# Epoch 92/100
# 23/23 - 0s - loss: 2.9752e-05 - accuracy: 1.0000 - val_loss: 0.0241 - val_accuracy: 0.9888
# Epoch 93/100
# 23/23 - 0s - loss: 3.0352e-05 - accuracy: 1.0000 - val_loss: 0.0254 - val_accuracy: 0.9832
# Epoch 94/100
# 23/23 - 0s - loss: 2.8336e-05 - accuracy: 1.0000 - val_loss: 0.0254 - val_accuracy: 0.9860
# Epoch 95/100
# 23/23 - 0s - loss: 2.6994e-05 - accuracy: 1.0000 - val_loss: 0.0266 - val_accuracy: 0.9860
# Epoch 96/100
# 23/23 - 0s - loss: 2.8063e-05 - accuracy: 1.0000 - val_loss: 0.0249 - val_accuracy: 0.9860
# Epoch 97/100
# 23/23 - 0s - loss: 2.6032e-05 - accuracy: 1.0000 - val_loss: 0.0256 - val_accuracy: 0.9860
# Epoch 98/100
# 23/23 - 0s - loss: 2.5343e-05 - accuracy: 1.0000 - val_loss: 0.0246 - val_accuracy: 0.9888
# Epoch 99/100
# 23/23 - 0s - loss: 2.4481e-05 - accuracy: 1.0000 - val_loss: 0.0260 - val_accuracy: 0.9860
# Epoch 100/100
# 23/23 - 0s - loss: 2.3867e-05 - accuracy: 1.0000 - val_loss: 0.0256 - val_accuracy: 0.9860

# %% [markdown]
# ## Save history

# %%
history2csv(history, KZ_CHARACTERS_HISTORY_FILE)
# Out:
# Saving history to CSV file
# 	Done

# %% [markdown]
# ## Charts

# %% [markdown]
# Reading the whole training history.

# %%
history = csv2history(KZ_CHARACTERS_HISTORY_FILE)
# Out:
# Reading history from CSV file
# 	Done

# %%
x = np.linspace(start=1, stop=history['epochs'], num=history['epochs'])

fig, (loss_chart, acc_chart) = plt.subplots(2)

fig.set_size_inches((24, 16))

loss_chart.set_title('Loss')
loss_chart.plot(x, history['loss'], label='loss')
loss_chart.plot(x, history['val_loss'], label='val_loss')
loss_chart.grid(b=True, color='gray', alpha=0.5, linestyle='dashdot')
loss_chart.legend(bbox_to_anchor=(0.0, 1.02, 1.0, 0.102), loc='lower left', ncol=2, mode="expand", borderaxespad=0.0)

acc_chart.set_title('Accuracy')
acc_chart.plot(x, history['accuracy'], label='accuracy')
acc_chart.plot(x, history['val_accuracy'], label='val_accuracy')
acc_chart.grid(b=True, color='gray', alpha=0.5, linestyle='dashdot')
acc_chart.legend(bbox_to_anchor=(0.0, 1.02, 1.0, 0.102), loc='lower left', ncol=2, mode="expand", borderaxespad=0.0)

plt.show()

# %%
test_loss, test_accuracy = model.evaluate(val_data, val_labels_cat, batch_size=64)
print('Test loss: %.4f accuracy: %.4f' % (test_loss, test_accuracy))
# Out:
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0256 - accuracy: 0.9860
# Test loss: 0.0256 accuracy: 0.9860

# %%
for classname_index, classname_path in enumerate(classname_paths):
    image_pathes = list(map(lambda filename: os.path.join(classname_path, filename), os.listdir(classname_path)[:1]))
    for image_path in image_pathes:
        image = cv2.imread(image_path)
        prepared_image = image.astype('float32') / 255
        score = model.predict(np.array([prepared_image]))

        plt.imshow(image)
        plt.title(classnames[np.argmax(score[0])])
        plt.show()
