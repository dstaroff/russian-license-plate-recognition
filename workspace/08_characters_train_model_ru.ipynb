# %% [markdown]
# # Step 8: Training characters classifier

# %% [markdown]
# ## Imports

# %%
import os

import cv2
import matplotlib.pyplot as plt
import numpy as np
from tensorflow import keras
from tensorflow.keras.callbacks import ModelCheckpoint

from src.local_utils.constants import (
    RU_CHARACTERS_IMAGES_PATH,
    RU_CHARACTERS_BEST_MODEL_FILE,
    RU_CHARACTERS_HISTORY_FILE,
    VALIDATION_SPLIT
)
from src.local_utils.history import history2csv, csv2history
from src.networks.character_classifier import CharacterClassifier

# %% [markdown]
# ## Preparing the data

# %%
X = []
Y = []

classnames = os.listdir(RU_CHARACTERS_IMAGES_PATH)
classname_paths = list(map(lambda clsname: os.path.join(RU_CHARACTERS_IMAGES_PATH, clsname), classnames))
for classname_index, classname_path in enumerate(classname_paths):
    image_pathes = list(map(lambda filename: os.path.join(classname_path, filename), os.listdir(classname_path)))
    for image_path in image_pathes:
        image = cv2.imread(image_path)
        X.append(image.astype('float32') / 255)
        Y.append(classname_index)

X = np.array(X)
Y = keras.utils.to_categorical(np.array(Y))

indexes = None
for _ in range(5):
    indexes = np.random.permutation(len(X))

train_data = X[indexes]
train_labels_cat = Y[indexes]

# now set-aside 10% of the train_data/labels as the
# cross-validation sets
val_count = int(VALIDATION_SPLIT * len(train_data))

# first pick validation set from train_data/labels
val_data = train_data[:val_count,:]
val_labels_cat = train_labels_cat[:val_count,:]

# leave rest in training set
train_data2 = train_data[val_count:,:]
train_labels_cat2 = train_labels_cat[val_count:,:]

# %% [markdown]
# ## Loading model

# %%
model = CharacterClassifier(len(classnames))

# %%
if os.path.exists(RU_CHARACTERS_BEST_MODEL_FILE):
    model.load_weights(RU_CHARACTERS_BEST_MODEL_FILE)

# %% [markdown]
# ## Training model

# %%
history = model.fit(
    train_data2,
    train_labels_cat2,
    epochs=100,
    batch_size=64,
    validation_data=(val_data, val_labels_cat),
    verbose=2,
    callbacks=[
        ModelCheckpoint(
            filepath=RU_CHARACTERS_BEST_MODEL_FILE,
            save_weights_only=True,
            monitor='val_accuracy',
            mode='max',
            save_best_only=True,
        )
    ]
)
# Out:
# Epoch 1/100
# 19/19 - 0s - loss: 1.1808 - accuracy: 0.8253 - val_loss: 0.2583 - val_accuracy: 0.9205
# Epoch 2/100
# 19/19 - 0s - loss: 0.1628 - accuracy: 0.9594 - val_loss: 0.1105 - val_accuracy: 0.9603
# Epoch 3/100
# 19/19 - 0s - loss: 0.0901 - accuracy: 0.9685 - val_loss: 0.0961 - val_accuracy: 0.9702
# Epoch 4/100
# 19/19 - 0s - loss: 0.0777 - accuracy: 0.9768 - val_loss: 0.0615 - val_accuracy: 0.9735
# Epoch 5/100
# 19/19 - 0s - loss: 0.0679 - accuracy: 0.9760 - val_loss: 0.1084 - val_accuracy: 0.9735
# Epoch 6/100
# 19/19 - 0s - loss: 0.0539 - accuracy: 0.9801 - val_loss: 0.0624 - val_accuracy: 0.9735
# Epoch 7/100
# 19/19 - 0s - loss: 0.0442 - accuracy: 0.9892 - val_loss: 0.0885 - val_accuracy: 0.9768
# Epoch 8/100
# 19/19 - 0s - loss: 0.0534 - accuracy: 0.9851 - val_loss: 0.0741 - val_accuracy: 0.9801
# Epoch 9/100
# 19/19 - 0s - loss: 0.0624 - accuracy: 0.9793 - val_loss: 0.0805 - val_accuracy: 0.9801
# Epoch 10/100
# 19/19 - 0s - loss: 0.0452 - accuracy: 0.9892 - val_loss: 0.0735 - val_accuracy: 0.9801
# Epoch 11/100
# 19/19 - 0s - loss: 0.0315 - accuracy: 0.9925 - val_loss: 0.0553 - val_accuracy: 0.9801
# Epoch 12/100
# 19/19 - 0s - loss: 0.0265 - accuracy: 0.9892 - val_loss: 0.0553 - val_accuracy: 0.9768
# Epoch 13/100
# 19/19 - 0s - loss: 0.0216 - accuracy: 0.9950 - val_loss: 0.0730 - val_accuracy: 0.9768
# Epoch 14/100
# 19/19 - 0s - loss: 0.0410 - accuracy: 0.9901 - val_loss: 0.0508 - val_accuracy: 0.9868
# Epoch 15/100
# 19/19 - 0s - loss: 0.0267 - accuracy: 0.9942 - val_loss: 0.0687 - val_accuracy: 0.9801
# Epoch 16/100
# 19/19 - 0s - loss: 0.0252 - accuracy: 0.9925 - val_loss: 0.0731 - val_accuracy: 0.9768
# Epoch 17/100
# 19/19 - 0s - loss: 0.0420 - accuracy: 0.9884 - val_loss: 0.0511 - val_accuracy: 0.9901
# Epoch 18/100
# 19/19 - 0s - loss: 0.0318 - accuracy: 0.9959 - val_loss: 0.0402 - val_accuracy: 0.9834
# Epoch 19/100
# 19/19 - 0s - loss: 0.0210 - accuracy: 0.9942 - val_loss: 0.0490 - val_accuracy: 0.9702
# Epoch 20/100
# 19/19 - 0s - loss: 0.0290 - accuracy: 0.9925 - val_loss: 0.0485 - val_accuracy: 0.9801
# Epoch 21/100
# 19/19 - 0s - loss: 0.0198 - accuracy: 0.9942 - val_loss: 0.0294 - val_accuracy: 0.9834
# Epoch 22/100
# 19/19 - 0s - loss: 0.0142 - accuracy: 0.9942 - val_loss: 0.0410 - val_accuracy: 0.9934
# Epoch 23/100
# 19/19 - 0s - loss: 0.0281 - accuracy: 0.9925 - val_loss: 0.0415 - val_accuracy: 0.9868
# Epoch 24/100
# 19/19 - 0s - loss: 0.0118 - accuracy: 0.9967 - val_loss: 0.0456 - val_accuracy: 0.9801
# Epoch 25/100
# 19/19 - 0s - loss: 0.0072 - accuracy: 0.9983 - val_loss: 0.0454 - val_accuracy: 0.9868
# Epoch 26/100
# 19/19 - 0s - loss: 0.0144 - accuracy: 0.9959 - val_loss: 0.0378 - val_accuracy: 0.9834
# Epoch 27/100
# 19/19 - 0s - loss: 0.0091 - accuracy: 0.9975 - val_loss: 0.0316 - val_accuracy: 0.9868
# Epoch 28/100
# 19/19 - 0s - loss: 0.0092 - accuracy: 0.9983 - val_loss: 0.0308 - val_accuracy: 0.9901
# Epoch 29/100
# 19/19 - 0s - loss: 0.0044 - accuracy: 0.9992 - val_loss: 0.0229 - val_accuracy: 0.9868
# Epoch 30/100
# 19/19 - 0s - loss: 0.0067 - accuracy: 0.9975 - val_loss: 0.0762 - val_accuracy: 0.9735
# Epoch 31/100
# 19/19 - 0s - loss: 0.0250 - accuracy: 0.9934 - val_loss: 0.0348 - val_accuracy: 0.9901
# Epoch 32/100
# 19/19 - 0s - loss: 0.0106 - accuracy: 0.9975 - val_loss: 0.0148 - val_accuracy: 0.9901
# Epoch 33/100
# 19/19 - 0s - loss: 0.0061 - accuracy: 0.9983 - val_loss: 0.0170 - val_accuracy: 0.9901
# Epoch 34/100
# 19/19 - 0s - loss: 0.0066 - accuracy: 0.9975 - val_loss: 0.0373 - val_accuracy: 0.9901
# Epoch 35/100
# 19/19 - 0s - loss: 0.0100 - accuracy: 0.9983 - val_loss: 0.0341 - val_accuracy: 0.9834
# Epoch 36/100
# 19/19 - 0s - loss: 0.0070 - accuracy: 0.9983 - val_loss: 0.0496 - val_accuracy: 0.9868
# Epoch 37/100
# 19/19 - 0s - loss: 0.0086 - accuracy: 0.9983 - val_loss: 0.0312 - val_accuracy: 0.9901
# Epoch 38/100
# 19/19 - 0s - loss: 0.0042 - accuracy: 0.9992 - val_loss: 0.0168 - val_accuracy: 0.9934
# Epoch 39/100
# 19/19 - 0s - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0168 - val_accuracy: 0.9934
# Epoch 40/100
# 19/19 - 0s - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0218 - val_accuracy: 0.9934
# Epoch 41/100
# 19/19 - 0s - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0196 - val_accuracy: 0.9934
# Epoch 42/100
# 19/19 - 0s - loss: 9.3056e-04 - accuracy: 1.0000 - val_loss: 0.0190 - val_accuracy: 0.9934
# Epoch 43/100
# 19/19 - 0s - loss: 6.1549e-04 - accuracy: 1.0000 - val_loss: 0.0171 - val_accuracy: 0.9934
# Epoch 44/100
# 19/19 - 0s - loss: 5.1306e-04 - accuracy: 1.0000 - val_loss: 0.0196 - val_accuracy: 0.9934
# Epoch 45/100
# 19/19 - 0s - loss: 5.7569e-04 - accuracy: 1.0000 - val_loss: 0.0185 - val_accuracy: 0.9934
# Epoch 46/100
# 19/19 - 0s - loss: 7.8627e-04 - accuracy: 1.0000 - val_loss: 0.0199 - val_accuracy: 0.9934
# Epoch 47/100
# 19/19 - 0s - loss: 5.9520e-04 - accuracy: 1.0000 - val_loss: 0.0191 - val_accuracy: 0.9934
# Epoch 48/100
# 19/19 - 0s - loss: 3.6207e-04 - accuracy: 1.0000 - val_loss: 0.0183 - val_accuracy: 0.9934
# Epoch 49/100
# 19/19 - 0s - loss: 4.0600e-04 - accuracy: 1.0000 - val_loss: 0.0195 - val_accuracy: 0.9934
# Epoch 50/100
# 19/19 - 0s - loss: 2.3313e-04 - accuracy: 1.0000 - val_loss: 0.0207 - val_accuracy: 0.9934
# Epoch 51/100
# 19/19 - 0s - loss: 2.9915e-04 - accuracy: 1.0000 - val_loss: 0.0190 - val_accuracy: 0.9934
# Epoch 52/100
# 19/19 - 0s - loss: 2.1726e-04 - accuracy: 1.0000 - val_loss: 0.0179 - val_accuracy: 0.9934
# Epoch 53/100
# 19/19 - 0s - loss: 2.3400e-04 - accuracy: 1.0000 - val_loss: 0.0190 - val_accuracy: 0.9934
# Epoch 54/100
# 19/19 - 0s - loss: 1.9951e-04 - accuracy: 1.0000 - val_loss: 0.0192 - val_accuracy: 0.9934
# Epoch 55/100
# 19/19 - 0s - loss: 1.7856e-04 - accuracy: 1.0000 - val_loss: 0.0182 - val_accuracy: 0.9934
# Epoch 56/100
# 19/19 - 0s - loss: 1.6388e-04 - accuracy: 1.0000 - val_loss: 0.0188 - val_accuracy: 0.9934
# Epoch 57/100
# 19/19 - 0s - loss: 1.7902e-04 - accuracy: 1.0000 - val_loss: 0.0185 - val_accuracy: 0.9934
# Epoch 58/100
# 19/19 - 0s - loss: 1.6348e-04 - accuracy: 1.0000 - val_loss: 0.0188 - val_accuracy: 0.9934
# Epoch 59/100
# 19/19 - 0s - loss: 1.4886e-04 - accuracy: 1.0000 - val_loss: 0.0186 - val_accuracy: 0.9934
# Epoch 60/100
# 19/19 - 0s - loss: 1.3656e-04 - accuracy: 1.0000 - val_loss: 0.0186 - val_accuracy: 0.9934
# Epoch 61/100
# 19/19 - 0s - loss: 1.3868e-04 - accuracy: 1.0000 - val_loss: 0.0187 - val_accuracy: 0.9934
# Epoch 62/100
# 19/19 - 0s - loss: 1.3204e-04 - accuracy: 1.0000 - val_loss: 0.0188 - val_accuracy: 0.9934
# Epoch 63/100
# 19/19 - 0s - loss: 1.2756e-04 - accuracy: 1.0000 - val_loss: 0.0186 - val_accuracy: 0.9934
# Epoch 64/100
# 19/19 - 0s - loss: 1.2574e-04 - accuracy: 1.0000 - val_loss: 0.0189 - val_accuracy: 0.9934
# Epoch 65/100
# 19/19 - 0s - loss: 1.3248e-04 - accuracy: 1.0000 - val_loss: 0.0191 - val_accuracy: 0.9934
# Epoch 66/100
# 19/19 - 0s - loss: 1.2243e-04 - accuracy: 1.0000 - val_loss: 0.0188 - val_accuracy: 0.9934
# Epoch 67/100
# 19/19 - 0s - loss: 1.0872e-04 - accuracy: 1.0000 - val_loss: 0.0186 - val_accuracy: 0.9934
# Epoch 68/100
# 19/19 - 0s - loss: 1.2303e-04 - accuracy: 1.0000 - val_loss: 0.0190 - val_accuracy: 0.9934
# Epoch 69/100
# 19/19 - 0s - loss: 1.1146e-04 - accuracy: 1.0000 - val_loss: 0.0190 - val_accuracy: 0.9934
# Epoch 70/100
# 19/19 - 0s - loss: 1.0115e-04 - accuracy: 1.0000 - val_loss: 0.0190 - val_accuracy: 0.9934
# Epoch 71/100
# 19/19 - 0s - loss: 1.0251e-04 - accuracy: 1.0000 - val_loss: 0.0187 - val_accuracy: 0.9934
# Epoch 72/100
# 19/19 - 0s - loss: 9.4011e-05 - accuracy: 1.0000 - val_loss: 0.0187 - val_accuracy: 0.9934
# Epoch 73/100
# 19/19 - 0s - loss: 9.1104e-05 - accuracy: 1.0000 - val_loss: 0.0189 - val_accuracy: 0.9934
# Epoch 74/100
# 19/19 - 0s - loss: 8.6287e-05 - accuracy: 1.0000 - val_loss: 0.0188 - val_accuracy: 0.9934
# Epoch 75/100
# 19/19 - 0s - loss: 8.5279e-05 - accuracy: 1.0000 - val_loss: 0.0188 - val_accuracy: 0.9934
# Epoch 76/100
# 19/19 - 0s - loss: 8.9028e-05 - accuracy: 1.0000 - val_loss: 0.0189 - val_accuracy: 0.9934
# Epoch 77/100
# 19/19 - 0s - loss: 9.2706e-05 - accuracy: 1.0000 - val_loss: 0.0188 - val_accuracy: 0.9934
# Epoch 78/100
# 19/19 - 0s - loss: 9.3822e-05 - accuracy: 1.0000 - val_loss: 0.0188 - val_accuracy: 0.9934
# Epoch 79/100
# 19/19 - 0s - loss: 7.3792e-05 - accuracy: 1.0000 - val_loss: 0.0188 - val_accuracy: 0.9934
# Epoch 80/100
# 19/19 - 0s - loss: 7.3193e-05 - accuracy: 1.0000 - val_loss: 0.0188 - val_accuracy: 0.9934
# Epoch 81/100
# 19/19 - 0s - loss: 7.4033e-05 - accuracy: 1.0000 - val_loss: 0.0188 - val_accuracy: 0.9934
# Epoch 82/100
# 19/19 - 0s - loss: 7.0505e-05 - accuracy: 1.0000 - val_loss: 0.0188 - val_accuracy: 0.9934
# Epoch 83/100
# 19/19 - 0s - loss: 6.8197e-05 - accuracy: 1.0000 - val_loss: 0.0182 - val_accuracy: 0.9934
# Epoch 84/100
# 19/19 - 0s - loss: 7.0179e-05 - accuracy: 1.0000 - val_loss: 0.0188 - val_accuracy: 0.9934
# Epoch 85/100
# 19/19 - 0s - loss: 6.8380e-05 - accuracy: 1.0000 - val_loss: 0.0186 - val_accuracy: 0.9934
# Epoch 86/100
# 19/19 - 0s - loss: 7.2917e-05 - accuracy: 1.0000 - val_loss: 0.0183 - val_accuracy: 0.9934
# Epoch 87/100
# 19/19 - 0s - loss: 6.9900e-05 - accuracy: 1.0000 - val_loss: 0.0178 - val_accuracy: 0.9934
# Epoch 88/100
# 19/19 - 0s - loss: 6.6241e-05 - accuracy: 1.0000 - val_loss: 0.0185 - val_accuracy: 0.9934
# Epoch 89/100
# 19/19 - 0s - loss: 6.2053e-05 - accuracy: 1.0000 - val_loss: 0.0189 - val_accuracy: 0.9934
# Epoch 90/100
# 19/19 - 0s - loss: 5.9386e-05 - accuracy: 1.0000 - val_loss: 0.0181 - val_accuracy: 0.9934
# Epoch 91/100
# 19/19 - 0s - loss: 5.4433e-05 - accuracy: 1.0000 - val_loss: 0.0183 - val_accuracy: 0.9934
# Epoch 92/100
# 19/19 - 0s - loss: 5.3911e-05 - accuracy: 1.0000 - val_loss: 0.0186 - val_accuracy: 0.9934
# Epoch 93/100
# 19/19 - 0s - loss: 5.1812e-05 - accuracy: 1.0000 - val_loss: 0.0183 - val_accuracy: 0.9934
# Epoch 94/100
# 19/19 - 0s - loss: 5.0935e-05 - accuracy: 1.0000 - val_loss: 0.0183 - val_accuracy: 0.9934
# Epoch 95/100
# 19/19 - 0s - loss: 5.4525e-05 - accuracy: 1.0000 - val_loss: 0.0187 - val_accuracy: 0.9934
# Epoch 96/100
# 19/19 - 0s - loss: 5.0269e-05 - accuracy: 1.0000 - val_loss: 0.0183 - val_accuracy: 0.9934
# Epoch 97/100
# 19/19 - 0s - loss: 4.9296e-05 - accuracy: 1.0000 - val_loss: 0.0180 - val_accuracy: 0.9934
# Epoch 98/100
# 19/19 - 0s - loss: 4.8389e-05 - accuracy: 1.0000 - val_loss: 0.0185 - val_accuracy: 0.9934
# Epoch 99/100
# 19/19 - 0s - loss: 4.7027e-05 - accuracy: 1.0000 - val_loss: 0.0183 - val_accuracy: 0.9934
# Epoch 100/100
# 19/19 - 0s - loss: 4.5390e-05 - accuracy: 1.0000 - val_loss: 0.0185 - val_accuracy: 0.9934

# %% [markdown]
# ## Save history

# %%
history2csv(history, RU_CHARACTERS_HISTORY_FILE)
# Out:
# Saving history to CSV file
# 	Done

# %% [markdown]
# ## Charts

# %% [markdown]
# Reading the whole training history.

# %%
history = csv2history(RU_CHARACTERS_HISTORY_FILE)
# Out:
# Reading history from CSV file
# 	Done

# %%
x = np.linspace(start=1, stop=history['epochs'], num=history['epochs'])

fig, (loss_chart, acc_chart) = plt.subplots(2)

fig.set_size_inches((24, 16))

loss_chart.set_title('Loss')
loss_chart.plot(x, history['loss'], label='loss')
loss_chart.plot(x, history['val_loss'], label='val_loss')
loss_chart.grid(b=True, color='gray', alpha=0.5, linestyle='dashdot')
loss_chart.legend(bbox_to_anchor=(0.0, 1.02, 1.0, 0.102), loc='lower left', ncol=2, mode="expand", borderaxespad=0.0)

acc_chart.set_title('Accuracy')
acc_chart.plot(x, history['accuracy'], label='accuracy')
acc_chart.plot(x, history['val_accuracy'], label='val_accuracy')
acc_chart.grid(b=True, color='gray', alpha=0.5, linestyle='dashdot')
acc_chart.legend(bbox_to_anchor=(0.0, 1.02, 1.0, 0.102), loc='lower left', ncol=2, mode="expand", borderaxespad=0.0)

plt.show()

# %%
test_loss, test_accuracy = model.evaluate(val_data, val_labels_cat, batch_size=64)
print('Test loss: %.4f accuracy: %.4f' % (test_loss, test_accuracy))
# Out:
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0185 - accuracy: 0.9934
# Test loss: 0.0185 accuracy: 0.9934

# %%
for classname_index, classname_path in enumerate(classname_paths):
    image_pathes = list(map(lambda filename: os.path.join(classname_path, filename), os.listdir(classname_path)[:1]))
    for image_path in image_pathes:
        image = cv2.imread(image_path)
        prepared_image = image.astype('float32') / 255
        score = model.predict(np.array([prepared_image]))

        plt.imshow(image)
        plt.title(classnames[np.argmax(score[0])])
        plt.show()
